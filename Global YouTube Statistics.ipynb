# %%
import numpy as np
import pandas as pd
import chardet
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
data = pd.read_csv('Global YouTube Statistics.csv', encoding='latin-1')
data.head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
# Fill numerical columns with their median
numeric_columns = data.select_dtypes(include=['number']).columns
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].median())

# Fill categorical columns with their mode
categorical_columns = data.select_dtypes(exclude=['number']).columns
for column in categorical_columns:
    data[column].fillna(data[column].mode().iloc[0], inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19096\218992189.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mode().iloc[0], inplace=True)

# %%
# Check if there are any remaining missing values
data.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.head(20)
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series    245000000  2.280000e+11
# 1      2              YouTube Movies    170000000  0.000000e+00
# 2      3                     MrBeast    166000000  2.836884e+10
# 3      4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4      5                   SET India    159000000  1.480000e+11
# 5      6                       Music    119000000  0.000000e+00
# 6      7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7      8                   PewDiePie    111000000  2.905804e+10
# 8      9                 Like Nastya    106000000  9.047906e+10
# 9     10               Vlad and Niki     98900000  7.718017e+10
# 10    11           Zee Music Company     96700000  5.785629e+10
# 11    12                         WWE     96000000  7.742847e+10
# 12    13                      Gaming     93600000  0.000000e+00
# 13    14                   BLACKPINK     89800000  3.214460e+10
# ...

# %%
data['created_date'] = pd.to_datetime(data['created_date'])

# %%
from datetime import datetime

data['channel_age_years'] = datetime.now().year - data['created_year']
data['view_to_subscriber_ratio'] = data['video views'] / data['subscribers']

# %%
sns.histplot(data['subscribers'], bins=30, kde=True)
plt.title('Distribution of Subscribers')
plt.show()

# %%
top_categories = data.groupby('category')['video views'].sum().sort_values(ascending=False).head(10)
top_categories.plot(kind='bar', color='skyblue')
plt.title('Top Categories by Video Views')
plt.ylabel('Total Video Views')
plt.show()

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=['number'])

# Plot heatmap for the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(x='subscribers', y='video views', data=data, hue='category')
plt.title('Subscribers vs. Video Views')
plt.show()

# %%
m = folium.Map(location=[data['Latitude'].mean(), data['Longitude'].mean()], zoom_start=2)

for _, row in data.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color='blue',
        fill=True,
        fill_opacity=0.6,
        tooltip=f"{row['Youtuber']} ({row['Country']})"
    ).add_to(m)

m.save("YouTube_Stats_Map.html")

# %%
top_earners = data.nlargest(10, 'highest_yearly_earnings')[['Youtuber', 'highest_yearly_earnings']]
print(top_earners)
# Out:
#                        Youtuber  highest_yearly_earnings
# 495            ýýýýýýýýý KIMPRO              163400000.0
# 417                DaFuq!?Boom!              110600000.0
# 0                      T-Series              108400000.0
# 302         KL BRO Biju Rithvik               97600000.0
# 3    Cocomelon - Nursery Rhymes               94800000.0
# 4                     SET India               87500000.0
# 21                       Zee TV               81900000.0
# 139                    StarPlus               80000000.0
# 15                     Sony SAB               79600000.0
# 83                  GR6 EXPLODE               78500000.0

# %%
data['growth_rate'] = (data['subscribers_for_last_30_days'] / data['subscribers']) * 100

# %%
data.to_csv('Cleaned_YouTube_Statistics.csv', index=False)
